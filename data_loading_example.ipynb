# %% [markdown]
# # imports

# %%
from data_loader import save_subjects, load_subjects

# %% [markdown]
# # save data from eegmmidb into .csv files

# %%
subject_dict = {'train': list(range(1, 80)), 'test': list(range(80, 110))}
runs = [4, 8, 12]

save_subjects(subject_dict, runs, max_length=656)
# Out:
# Extracting EDF parameters from /Users/marktaylor/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/marktaylor/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/marktaylor/mne_data/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# ...

# %% [markdown]
# # load into PyTorch data loaders

# %%
train_loader, test_loader = load_subjects(subject_dict, batch_size=6, shuffle=False)
